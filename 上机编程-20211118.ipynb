# %% [markdown]
# ## 《Python程序设计》2021秋季
# **<font size=4>上机编程(2021-11-18)</font>**
#
# **王晓宇&刘潇  机械科学与工程学院**
#
# - 1. 任意选择一个编程题，完成代码，下课前提交代码到1176651931@qq.com邮箱，根据代码的功能性和可读性进行评分，计入平时成绩
# ### <center><font color=#A52A2A size=5 >注意：邮件主题按照“Python上机编程-题目X-姓名-班级-学号”的格式填写</font></center>
# - 2. 下课后可继续完善代码，并结合自己编写的代码，谈谈对Python语言特点的理解，完成课程设计，根据代码和感想进行评分，计入结课成绩
#
# ### <center><font color=#A52A2A size=5 >注意：课程设计感想部分需要结合自己编写的代码展开，会查重，鼓励手写，不少于3000字，12月3日前按班级收齐提交，地点是机械大楼西楼A503</font></center>

# %% [markdown]
# # 1 完成代码，谈谈Python中可变与不可变对象的特点

# %% [markdown]
# ## 编写程序实现学生信息管理功能，包括添加、修改、删除和查看学生信息。要求（1）学生信息包括姓名、性别、学号等属性，（2）性别为男或者女，学号以大写字母开头，加上10位数字当类型不符合时报错，提示重新输入，（3）同学学生的姓名修改、删除和查看的性别、学号属性，（4）查看以格式化输出方式在屏幕显示。
# ![image.png](attachment:image.png)

# %%
student_info={} #存储学生信息

# %% [markdown]
# # 2 完成代码，谈谈Python函数的命名空间和作用域行为

# %% [markdown]
# ## 编写程序输出一个包含10行*3列1~100随机数的文件a.txt，定义函数对文件A的每一行数据按照指定列中数字从小到大的顺序进行重新排序，并输出文件a.txt和b.txt中的内容。
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # 3 完成代码，谈谈Python中一切皆对象和面向对象编程的特点

# %% [markdown]
# ## 编写学校成员类，具有成员姓名、年龄和总人数属性，教师类继承学校成员类，具有工号和工资属性，学生类继承学校成员类，具有学号和成绩属性。并实现如下功能：（1）创建对象时，总人数加1，对象注销时，总人数减1；（2）输出学生的平均成绩。
# ![image.png](attachment:image.png)
